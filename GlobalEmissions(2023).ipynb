# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
# Load the real global emissions file from the web:
url = "https://nyc3.digitaloceanspaces.com/owid-public/data/co2/owid-co2-data.csv"
df = pd.read_csv(url)

# %%
# Step 1 — filter to the year 2023:
df_2023 = df[df["year"] == 2023]

# %%
# Some rows are whole regions ("World", "Europe"), not real countries.
# Real countries have an ISO code; regions don't. Keep only real countries:
countries = df_2023[df_2023["iso_code"].notna()]

# %%
# Step 2 — sort by co2 (biggest first) and take the top 20:
top20 = countries.sort_values("co2", ascending=False).head(20)

# %%
# Show just the two columns we care about:
print(top20[["country", "co2"]])
# Out:
#                     country        co2
# 9885                  China  11902.503
# 47799         United States   4911.391
# 21658                 India   3062.324
# 38157                Russia   1815.925
# 23732                 Japan    988.785
# 22588                  Iran    817.880
# 40120          Saudi Arabia    736.205
# 21832             Indonesia    733.224
# 18230               Germany    596.151
# 42855           South Korea    577.417
# 8835                 Canada    549.299
# 7178                 Brazil    486.470
# 29571                Mexico    482.623
# 46049                Turkey    432.077
# 42233          South Africa    401.893
# 3661              Australia    382.972
# 49121               Vietnam    334.726
# 23284                 Italy    313.461
# 47575        United Kingdom    305.146
# 37457                Poland    289.282
# 28253              Malaysia    288.824
# 17299                France    272.476
# 13670                 Egypt    269.006
# ...

# %%
top20.plot(x="country", y="co2", kind="bar")

plt.show()
